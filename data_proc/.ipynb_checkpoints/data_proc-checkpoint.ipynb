# %%
# import modules
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sb
import numpy as np

# %%
data_serial = pd.read_csv("../data/serial_experiments.csv")
data_cuda = pd.read_csv("../data/cuda_experiments.csv")

# %%
data_serial['time [s]'].max()
# Out:
# 48.8855

# %%
data_serial[(data_serial['m']==1000)*(data_serial['n']==10)]['time [s]'].to_numpy().mean()
# Out:
# 0.00040066666666666663

# %%
ms = np.array([10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000])
ns = np.array([10, 50, 100, 500, 1000, 5000, 10000])

# %%
def avg(data):
    res = np.full((len(ms), len(ns)), np.nan)
    err = np.full((len(ms), len(ns)), np.nan)
    for mi, m in enumerate(ms):
        for ni, n in enumerate(ns):
            res[mi,ni] = np.mean(data[(data['m']==m)*(data['n']==n)]['time [s]'].to_numpy())
            err[mi,ni] = np.std(data[(data['m']==m)*(data['n']==n)]['time [s]'].to_numpy())
    return res, err

# %%
def speedup(serial, cuda):
    res = np.full((len(ms), len(ns)), np.nan)
    err = np.full((len(ms), len(ns)), np.nan)
    avg_serial, std_serial = avg(serial)
    avg_cuda, std_cuda = avg(cuda)
    res = avg_serial/avg_cuda
    err = (std_serial*avg_cuda + avg_serial*std_cuda) / avg_cuda**2
    return res, err

# %%
avg_serial, std_serial = avg(data_serial)
avg_cuda, std_cuda = avg(data_cuda)
avg_speedup, err_speedup = speedup(data_serial, data_cuda)

# %%
fig, ax = plt.subplots(1,2,figsize=(12,7))

im = ax[0].imshow(avg_serial, interpolation='none', vmin=1e-5, vmax=100, norm='log',
                  origin='lower')
ax[0].set_yticklabels([0, 10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000])
ax[0].set_xticklabels([0, 10, 50, 100, 500, 1000, 5000, 10000])
ax[0].set_ylabel('m')
ax[0].set_xlabel('n')
ax[0].set_title('Serial version')

ax[1].imshow(avg_cuda, interpolation='none', vmin=1e-5, vmax=100, norm='log',
                  origin='lower')
ax[1].set_yticklabels([0, 10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000])
ax[1].set_xticklabels([0, 10, 50, 100, 500, 1000, 5000, 10000])
# ax[1].set_ylabel('m')
ax[1].set_xlabel('n')
ax[1].set_title('CUDA version')

cax = fig.add_axes([0.27, -0.025, 0.5, 0.05])
cbar = fig.colorbar(im, cax=cax, orientation='horizontal', label='Time [s]')

fig.savefig('../img/time.png', dpi=300, bbox_inches='tight')
# Out:
# /tmp/ipykernel_20422/160664891.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_yticklabels([0, 10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000])
# /tmp/ipykernel_20422/160664891.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels([0, 10, 50, 100, 500, 1000, 5000, 10000])
# /tmp/ipykernel_20422/160664891.py:13: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_yticklabels([0, 10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000])
# /tmp/ipykernel_20422/160664891.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_xticklabels([0, 10, 50, 100, 500, 1000, 5000, 10000])

# %%
fig, ax = plt.subplots(1,2,figsize=(12,7))

speedup_min = 0
speedup_max = 1.4

im1 = ax[0].imshow(avg_speedup, interpolation='none', vmin=speedup_min, vmax=speedup_max,
                   norm='linear', origin='lower')
ax[0].set_yticklabels([0, 10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000])
ax[0].set_xticklabels([0, 10, 50, 100, 500, 1000, 5000, 10000])
ax[0].set_ylabel('m')
ax[0].set_xlabel('n')
ax[0].set_title('Speedup')

cax1 = fig.add_axes([0.15, -0.025, 0.3, 0.05])
cbar1 = fig.colorbar(im1, cax=cax1, orientation='horizontal')

im2 = ax[1].imshow(err_speedup, interpolation='none', vmin=0, vmax=1e-2, norm='linear',
                  origin='lower')
ax[1].set_yticklabels([0, 10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000])
ax[1].set_xticklabels([0, 10, 50, 100, 500, 1000, 5000, 10000])
# ax[1].set_ylabel('m')
ax[1].set_xlabel('n')
ax[1].set_title('Speedup error')

cax2 = fig.add_axes([0.575, -0.025, 0.3, 0.05])
cbar2 = fig.colorbar(im2, cax=cax2, orientation='horizontal')

fig.savefig('../img/speedup.png', dpi=300, bbox_inches='tight')
# Out:
# /tmp/ipykernel_20422/452059570.py:5: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_yticklabels([0, 10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000])
# /tmp/ipykernel_20422/452059570.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels([0, 10, 50, 100, 500, 1000, 5000, 10000])
# /tmp/ipykernel_20422/452059570.py:16: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_yticklabels([0, 10, 50, 100, 500, 1000, 5000, 10000, 50000, 100000])
# /tmp/ipykernel_20422/452059570.py:17: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_xticklabels([0, 10, 50, 100, 500, 1000, 5000, 10000])
